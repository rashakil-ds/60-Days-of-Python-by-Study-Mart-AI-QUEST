# %% [markdown]
# # input function

# %%
data = 'data science fun'

# %%
type(data)
# Out:
# str

# %%
data = input()
# Out:
# data science fun!

# %%
data
# Out:
# 'data science fun!'

# %%
type(data)
# Out:
# str

# %%
x = input()
y = input()
# Out:
# 10
# 20

# %%
x+y
# Out:
# '1020'

# %%
type(x)
# Out:
# str

# %%
type(y)
# Out:
# str

# %%
x = int(x)
y = int(y)

# %%
x+y
# Out:
# 30

# %%
type(x)
# Out:
# int

# %%
x  = int(input('Enter your 1st num: '))
# Out:
# Enter your 1st num: 200

# %%
x
# Out:
# 200

# %%
y  = int(input('Enter your 2nd num: '))
# Out:
# Enter your 2nd num: 10.5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-3e46230e187c> in <module>
# ----> 1 y  = int(input('Enter your 2nd num: '))
#
# ValueError: invalid literal for int() with base 10: '10.5'

# %%
y  = float(input('Enter your 2nd num: '))
# Out:
# Enter your 2nd num: 10.5

# %%
x+y
# Out:
# 210.5

# %%
data = '60 Days of python'

# %%
type(data)
# Out:
# str

# %%
len(data)
# Out:
# 17

# %%
import sys
sys.getsizeof(data)
# Out:
# 66

# %%
data.count('python')
# Out:
# 1

# %%
sub = 'Days of'

# %%
data.count(sub)
# Out:
# 1

# %% [markdown]
# # Python String Methods

# %%
data = '60 Days of python'
data.find('of')
# Out:
# 8

# %%
data.find('f') #find value from string
# Out:
# 9

# %%
data.find('y',6,10) #not exist
# Out:
# -1

# %%
data.find('y',6,14)
# Out:
# 12

# %%
data.index('y')
# Out:
# 5

# %%
data.index('y',6,13)
# Out:
# 12

# %%
data.index('ai')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-dc2f3200ece3> in <module>
# ----> 1 data.index('ai')
#
# ValueError: substring not found

# %%
data.lower() #convert all char into lower case
# Out:
# '60 days of python'

# %%
data.upper() #convert all char into upper case
# Out:
# '60 DAYS OF PYTHON'

# %%
data.casefold() #lower
# Out:
# '60 days of python'

# %%
x = 'data SCIENCE is Fun'

# %%
x.capitalize() #conver only first char into upper case
# Out:
# 'Data science is fun'

# %%
x.swapcase()
# Out:
# 'DATA science IS fUN'

# %%
x.title()
# Out:
# 'Data Science Is Fun'

# %%
x.islower()
# Out:
# False

# %%
x.upper()
# Out:
# 'DATA SCIENCE IS FUN'

# %%
x.isupper()
# Out:
# False

# %%
x.isdigit()
# Out:
# False

# %%
x.encode()
# Out:
# b'data SCIENCE is Fun'

# %%
type(x.encode())
# Out:
# bytes

# %%
x
# Out:
# 'data SCIENCE is Fun'

# %%
x.split()
# Out:
# ['data', 'SCIENCE', 'is', 'Fun']

# %%
x.split()[0]
# Out:
# 'data'

# %%
x.split()[1]
# Out:
# 'SCIENCE'

# %%
x.center(100)
# Out:
# '                                        data SCIENCE is Fun                                         '

# %%
x.replace('data','AI')
# Out:
# 'AI SCIENCE is Fun'

# %%
x = 10
y = 100
z = x*y

print('I have ',z,'taka')
# Out:
# I have  1000 taka

# %%
print('I have {} taka'.format(z))
# Out:
# I have 1000 taka
